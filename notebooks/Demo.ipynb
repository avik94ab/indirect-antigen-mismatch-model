# %%
import sys
sys.path.append('../code')
import pandas as pd
import math
import api

# %% [markdown]
# ## Flow Diagram

# %%
from IPython.display import display
from PIL import Image

path="../misc/FlowDia.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2100 at 0x7FF5C61B6A00>

# %% [markdown]
# ### Sample protein sequence

# %%
seq = api.fetchSequence("P35329")

# %% [markdown]
# ### Generate peptides

# %%
peptides = api.generatePeptides(seq, 15, 5)

# %% [markdown]
# ### Generate DataFrame
#         Rows: Peptides
#         Columns: Alleles
#         Values: 0->Non-binder, 1->Binder

# %%
display(api.bindingScore(peptides))
# Out:
#                 HLA-DRA1*01:01-DRB1*03:01 HLA-DRA1*01:01-DRB1*07:01
# MRVHYLWLLLILGHV                  0.164653                  0.312197
# LWLLLILGHVASARY                  0.432442                  0.622838
# ILGHVASARYSSAND                  0.291947                  0.527009
# ASARYSSANDWTVDH                  0.154935                  0.422745
# SSANDWTVDHPQTLF                  0.438861                  0.303958
# ...                                   ...                       ...
# VNPSCPEDESIHYSE                    0.1347                  0.083257
# PEDESIHYSELVQFG                  0.340042                  0.434202
# IHYSELVQFGAGKRP                  0.258762                  0.364457
# LVQFGAGKRPQAKED                  0.174619                  0.246352
# AGKRPQAKEDVDYVT                  0.158512                  0.112072
#
# [171 rows x 2 columns]
